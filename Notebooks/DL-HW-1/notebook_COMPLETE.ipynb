# %% [markdown]
# # Deep Learning Homework 1 - scRNA-seq Classification
#
# **Objetivo:** Clasificacion multiclase de tipos celulares usando perfiles de expresion genica

# %% [markdown]
# ## 1. Importar Librerias y Configuracion Inicial

# %%
import numpy as np
import sys, os
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# Reproducibilidad
np.random.seed(42)

# Configuracion
plt.style.use('default')
sns.set_palette('husl')
# %matplotlib inline
